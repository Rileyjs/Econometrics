# %%
# Libraries
# Libraries being used\n",
''' To install new libraries all install commands should bei n the anaconda terminal.
    "Open Anaconda Prompt -> type: activate projectName -> then the install command (pip or conda)'''
import pandas as pd
import scikit
import os
# pip install fredapi
# https://github.com/mortada/fredapi documentation
from fredapi import Fred
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-b7726c69d127> in <module>
#       4     "Open Anaconda Prompt -> type: activate projectName -> then the install command (pip or conda)'''
#       5 import pandas as pd
# ----> 6 import matplotlib
#       7 import scikit
#       8 import os
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# Loading Data sets
df = pd.read_csv(os.path.join("data", "Log Differences GDPC1.csv"))
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Columns: 333 entries, datestr to GDPC1_20190101logdifference
# dtypes: float64(328), int64(2), object(3)
# memory usage: 611.4+ KB

# %%
# Stripping down douplicate columns
column_counts = {}
for column_name in df.columns:
    if column_name[:-15] in column_counts:
        column_counts[column_name[:-15]].append(column_name)
    else:
        column_counts[column_name[:-15]] = [column_name]
        
duplicates = []
for column_name in column_counts:
    if len(column_counts[column_name]) > 1:
        duplicates.append(column_counts[column_name])

# First index always has non-time series columns
for i in duplicates[1:]:
    for key in i[:-1]:
        df.drop(key, axis="columns", inplace=True)
        
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Columns: 323 entries, datestr to GDPC1_20190101logdifference
# dtypes: float64(318), int64(2), object(3)
# memory usage: 593.1+ KB

# %%
# Trimming all column names (removing day and string logdifference)
df = df.rename(columns = {original:original[:-15] for original in df.columns if "GDP" in original})

print(df.columns)
df.info()
# Out:
# Index(['datestr', 'daten', 'newyq', 'Year', 'qrt', 'GDPC1_199112',
#        'GDPC1_199201', 'GDPC1_199202', 'GDPC1_199203', 'GDPC1_199204',
#        ...
#        'GDPC1_201804', 'GDPC1_201805', 'GDPC1_201806', 'GDPC1_201807',
#        'GDPC1_201808', 'GDPC1_201809', 'GDPC1_201810', 'GDPC1_201811',
#        'GDPC1_201812', 'GDPC1_201901'],
#       dtype='object', length=323)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 235 entries, 0 to 234
# Columns: 323 entries, datestr to GDPC1_201901
# dtypes: float64(318), int64(2), object(3)
# memory usage: 593.1+ KB

# %%
# Save all data sets
df.to_csv(os.path.join("data", "Cleaned_log_diff_GDP.csv"))

# %%
# Now dealing with unrate
unrate = pd.read_csv(os.path.join("data", "UNRATE vintages.csv"))
t = unrate.transpose()
t.columns = t.iloc[0]
t
#temp = t['datestr']
#t.groupby(pd.PeriodIndex(df.columns[1:], freq='Q'), axis=1).mean()
# Out:
# datestr          1960-01-01  1960-02-01  1960-03-01  1960-04-01  1960-05-01  \
# datestr          1960-01-01  1960-02-01  1960-03-01  1960-04-01  1960-05-01
# daten             01jan1960   01feb1960   01mar1960   01apr1960   01may1960
# UNRATE_19911206         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920110         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920207         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920306         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920403         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920508         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920605         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920702         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920807         5.2         4.8         5.4         5.2         5.1
# UNRATE_19920904         5.2         4.8         5.4         5.2         5.1
# UNRATE_19921002         5.2         4.8         5.4         5.2         5.1
# UNRATE_19921106         5.2         4.8         5.4         5.2         5.1
# UNRATE_19921204         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930108         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930205         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930305         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930402         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930507         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930604         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930702         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930806         5.2         4.8         5.4         5.2         5.1
# UNRATE_19930903         5.2         4.8         5.4         5.2         5.1
# UNRATE_19931008         5.2         4.8         5.4         5.2         5.1
# UNRATE_19931105         5.2         4.8         5.4         5.2         5.1
# UNRATE_19931203         5.2         4.8         5.4         5.2         5.1
# UNRATE_19940107         5.2         4.8         5.4         5.2         5.1
# UNRATE_19940204         5.2         4.8         5.4         5.2         5.1
# UNRATE_19940304         5.2         4.8         5.4         5.2         5.1
# ...                     ...         ...         ...         ...         ...
# UNRATE_20160805         5.2         4.8         5.4         5.2         5.1
# UNRATE_20160902         5.2         4.8         5.4         5.2         5.1
# UNRATE_20161007         5.2         4.8         5.4         5.2         5.1
# UNRATE_20161104         5.2         4.8         5.4         5.2         5.1
# UNRATE_20161202         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170106         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170203         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170310         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170407         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170505         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170602         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170707         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170804         5.2         4.8         5.4         5.2         5.1
# UNRATE_20170901         5.2         4.8         5.4         5.2         5.1
# UNRATE_20171006         5.2         4.8         5.4         5.2         5.1
# UNRATE_20171103         5.2         4.8         5.4         5.2         5.1
# UNRATE_20171208         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180105         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180202         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180309         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180406         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180504         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180601         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180706         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180803         5.2         4.8         5.4         5.2         5.1
# UNRATE_20180907         5.2         4.8         5.4         5.2         5.1
# UNRATE_20181005         5.2         4.8         5.4         5.2         5.1
# UNRATE_20181102         5.2         4.8         5.4         5.2         5.1
# UNRATE_20181207         5.2         4.8         5.4         5.2         5.1
# UNRATE_20190101         5.2         4.8         5.4         5.2         5.1
#
# datestr          1960-06-01  1960-07-01  1960-08-01  1960-09-01  1960-10-01  \
# datestr          1960-06-01  1960-07-01  1960-08-01  1960-09-01  1960-10-01
# daten             01jun1960   01jul1960   01aug1960   01sep1960   01oct1960
# UNRATE_19911206         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920110         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920207         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920306         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920403         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920508         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920605         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920702         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920807         5.4         5.5         5.6         5.5         6.1
# UNRATE_19920904         5.4         5.5         5.6         5.5         6.1
# UNRATE_19921002         5.4         5.5         5.6         5.5         6.1
# UNRATE_19921106         5.4         5.5         5.6         5.5         6.1
# UNRATE_19921204         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930108         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930205         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930305         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930402         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930507         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930604         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930702         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930806         5.4         5.5         5.6         5.5         6.1
# UNRATE_19930903         5.4         5.5         5.6         5.5         6.1
# UNRATE_19931008         5.4         5.5         5.6         5.5         6.1
# UNRATE_19931105         5.4         5.5         5.6         5.5         6.1
# UNRATE_19931203         5.4         5.5         5.6         5.5         6.1
# UNRATE_19940107         5.4         5.5         5.6         5.5         6.1
# UNRATE_19940204         5.4         5.5         5.6         5.5         6.1
# UNRATE_19940304         5.4         5.5         5.6         5.5         6.1
# ...                     ...         ...         ...         ...         ...
# UNRATE_20160805         5.4         5.5         5.6         5.5         6.1
# UNRATE_20160902         5.4         5.5         5.6         5.5         6.1
# UNRATE_20161007         5.4         5.5         5.6         5.5         6.1
# UNRATE_20161104         5.4         5.5         5.6         5.5         6.1
# UNRATE_20161202         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170106         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170203         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170310         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170407         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170505         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170602         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170707         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170804         5.4         5.5         5.6         5.5         6.1
# UNRATE_20170901         5.4         5.5         5.6         5.5         6.1
# UNRATE_20171006         5.4         5.5         5.6         5.5         6.1
# UNRATE_20171103         5.4         5.5         5.6         5.5         6.1
# UNRATE_20171208         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180105         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180202         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180309         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180406         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180504         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180601         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180706         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180803         5.4         5.5         5.6         5.5         6.1
# UNRATE_20180907         5.4         5.5         5.6         5.5         6.1
# UNRATE_20181005         5.4         5.5         5.6         5.5         6.1
# UNRATE_20181102         5.4         5.5         5.6         5.5         6.1
# UNRATE_20181207         5.4         5.5         5.6         5.5         6.1
# UNRATE_20190101         5.4         5.5         5.6         5.5         6.1
#
# datestr          ...  2018-02-01  2018-03-01  2018-04-01  2018-05-01  \
# datestr          ...  2018-02-01  2018-03-01  2018-04-01  2018-05-01
# daten            ...   01feb2018   01mar2018   01apr2018   01may2018
# UNRATE_19911206  ...         NaN         NaN         NaN         NaN
# UNRATE_19920110  ...         NaN         NaN         NaN         NaN
# UNRATE_19920207  ...         NaN         NaN         NaN         NaN
# UNRATE_19920306  ...         NaN         NaN         NaN         NaN
# UNRATE_19920403  ...         NaN         NaN         NaN         NaN
# UNRATE_19920508  ...         NaN         NaN         NaN         NaN
# UNRATE_19920605  ...         NaN         NaN         NaN         NaN
# UNRATE_19920702  ...         NaN         NaN         NaN         NaN
# UNRATE_19920807  ...         NaN         NaN         NaN         NaN
# UNRATE_19920904  ...         NaN         NaN         NaN         NaN
# UNRATE_19921002  ...         NaN         NaN         NaN         NaN
# UNRATE_19921106  ...         NaN         NaN         NaN         NaN
# UNRATE_19921204  ...         NaN         NaN         NaN         NaN
# UNRATE_19930108  ...         NaN         NaN         NaN         NaN
# UNRATE_19930205  ...         NaN         NaN         NaN         NaN
# UNRATE_19930305  ...         NaN         NaN         NaN         NaN
# UNRATE_19930402  ...         NaN         NaN         NaN         NaN
# UNRATE_19930507  ...         NaN         NaN         NaN         NaN
# UNRATE_19930604  ...         NaN         NaN         NaN         NaN
# UNRATE_19930702  ...         NaN         NaN         NaN         NaN
# UNRATE_19930806  ...         NaN         NaN         NaN         NaN
# UNRATE_19930903  ...         NaN         NaN         NaN         NaN
# UNRATE_19931008  ...         NaN         NaN         NaN         NaN
# UNRATE_19931105  ...         NaN         NaN         NaN         NaN
# UNRATE_19931203  ...         NaN         NaN         NaN         NaN
# UNRATE_19940107  ...         NaN         NaN         NaN         NaN
# UNRATE_19940204  ...         NaN         NaN         NaN         NaN
# UNRATE_19940304  ...         NaN         NaN         NaN         NaN
# ...              ...         ...         ...         ...         ...
# UNRATE_20160805  ...         NaN         NaN         NaN         NaN
# UNRATE_20160902  ...         NaN         NaN         NaN         NaN
# UNRATE_20161007  ...         NaN         NaN         NaN         NaN
# UNRATE_20161104  ...         NaN         NaN         NaN         NaN
# UNRATE_20161202  ...         NaN         NaN         NaN         NaN
# UNRATE_20170106  ...         NaN         NaN         NaN         NaN
# UNRATE_20170203  ...         NaN         NaN         NaN         NaN
# UNRATE_20170310  ...         NaN         NaN         NaN         NaN
# UNRATE_20170407  ...         NaN         NaN         NaN         NaN
# UNRATE_20170505  ...         NaN         NaN         NaN         NaN
# UNRATE_20170602  ...         NaN         NaN         NaN         NaN
# UNRATE_20170707  ...         NaN         NaN         NaN         NaN
# UNRATE_20170804  ...         NaN         NaN         NaN         NaN
# UNRATE_20170901  ...         NaN         NaN         NaN         NaN
# UNRATE_20171006  ...         NaN         NaN         NaN         NaN
# UNRATE_20171103  ...         NaN         NaN         NaN         NaN
# UNRATE_20171208  ...         NaN         NaN         NaN         NaN
# UNRATE_20180105  ...         NaN         NaN         NaN         NaN
# UNRATE_20180202  ...         NaN         NaN         NaN         NaN
# UNRATE_20180309  ...         4.1         NaN         NaN         NaN
# UNRATE_20180406  ...         4.1         4.1         NaN         NaN
# UNRATE_20180504  ...         4.1         4.1         3.9         NaN
# UNRATE_20180601  ...         4.1         4.1         3.9         3.8
# UNRATE_20180706  ...         4.1         4.1         3.9         3.8
# UNRATE_20180803  ...         4.1         4.1         3.9         3.8
# UNRATE_20180907  ...         4.1         4.1         3.9         3.8
# UNRATE_20181005  ...         4.1         4.1         3.9         3.8
# UNRATE_20181102  ...         4.1         4.1         3.9         3.8
# UNRATE_20181207  ...         4.1         4.1         3.9         3.8
# UNRATE_20190101  ...         4.1         4.1         3.9         3.8
#
# datestr          2018-06-01  2018-07-01  2018-08-01  2018-09-01  2018-10-01  \
# datestr          2018-06-01  2018-07-01  2018-08-01  2018-09-01  2018-10-01
# daten             01jun2018   01jul2018   01aug2018   01sep2018   01oct2018
# UNRATE_19911206         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920110         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920207         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920306         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920403         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920508         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920605         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920702         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920807         NaN         NaN         NaN         NaN         NaN
# UNRATE_19920904         NaN         NaN         NaN         NaN         NaN
# UNRATE_19921002         NaN         NaN         NaN         NaN         NaN
# UNRATE_19921106         NaN         NaN         NaN         NaN         NaN
# UNRATE_19921204         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930108         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930205         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930305         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930402         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930507         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930604         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930702         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930806         NaN         NaN         NaN         NaN         NaN
# UNRATE_19930903         NaN         NaN         NaN         NaN         NaN
# UNRATE_19931008         NaN         NaN         NaN         NaN         NaN
# UNRATE_19931105         NaN         NaN         NaN         NaN         NaN
# UNRATE_19931203         NaN         NaN         NaN         NaN         NaN
# UNRATE_19940107         NaN         NaN         NaN         NaN         NaN
# UNRATE_19940204         NaN         NaN         NaN         NaN         NaN
# UNRATE_19940304         NaN         NaN         NaN         NaN         NaN
# ...                     ...         ...         ...         ...         ...
# UNRATE_20160805         NaN         NaN         NaN         NaN         NaN
# UNRATE_20160902         NaN         NaN         NaN         NaN         NaN
# UNRATE_20161007         NaN         NaN         NaN         NaN         NaN
# UNRATE_20161104         NaN         NaN         NaN         NaN         NaN
# UNRATE_20161202         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170106         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170203         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170310         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170407         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170505         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170602         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170707         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170804         NaN         NaN         NaN         NaN         NaN
# UNRATE_20170901         NaN         NaN         NaN         NaN         NaN
# UNRATE_20171006         NaN         NaN         NaN         NaN         NaN
# UNRATE_20171103         NaN         NaN         NaN         NaN         NaN
# UNRATE_20171208         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180105         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180202         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180309         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180406         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180504         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180601         NaN         NaN         NaN         NaN         NaN
# UNRATE_20180706           4         NaN         NaN         NaN         NaN
# UNRATE_20180803           4         3.9         NaN         NaN         NaN
# UNRATE_20180907           4         3.9         3.9         NaN         NaN
# UNRATE_20181005           4         3.9         3.9         3.7         NaN
# UNRATE_20181102           4         3.9         3.9         3.7         3.7
# UNRATE_20181207           4         3.9         3.9         3.7         3.7
# UNRATE_20190101           4         3.9         3.9         3.7         3.7
#
# datestr          2018-11-01
# datestr          2018-11-01
# daten             01nov2018
# UNRATE_19911206         NaN
# UNRATE_19920110         NaN
# UNRATE_19920207         NaN
# UNRATE_19920306         NaN
# UNRATE_19920403         NaN
# UNRATE_19920508         NaN
# UNRATE_19920605         NaN
# UNRATE_19920702         NaN
# UNRATE_19920807         NaN
# UNRATE_19920904         NaN
# UNRATE_19921002         NaN
# UNRATE_19921106         NaN
# UNRATE_19921204         NaN
# UNRATE_19930108         NaN
# UNRATE_19930205         NaN
# UNRATE_19930305         NaN
# UNRATE_19930402         NaN
# UNRATE_19930507         NaN
# UNRATE_19930604         NaN
# UNRATE_19930702         NaN
# UNRATE_19930806         NaN
# UNRATE_19930903         NaN
# UNRATE_19931008         NaN
# UNRATE_19931105         NaN
# UNRATE_19931203         NaN
# UNRATE_19940107         NaN
# UNRATE_19940204         NaN
# UNRATE_19940304         NaN
# ...                     ...
# UNRATE_20160805         NaN
# UNRATE_20160902         NaN
# UNRATE_20161007         NaN
# UNRATE_20161104         NaN
# UNRATE_20161202         NaN
# UNRATE_20170106         NaN
# UNRATE_20170203         NaN
# UNRATE_20170310         NaN
# UNRATE_20170407         NaN
# UNRATE_20170505         NaN
# UNRATE_20170602         NaN
# UNRATE_20170707         NaN
# UNRATE_20170804         NaN
# UNRATE_20170901         NaN
# UNRATE_20171006         NaN
# UNRATE_20171103         NaN
# UNRATE_20171208         NaN
# UNRATE_20180105         NaN
# UNRATE_20180202         NaN
# UNRATE_20180309         NaN
# UNRATE_20180406         NaN
# UNRATE_20180504         NaN
# UNRATE_20180601         NaN
# UNRATE_20180706         NaN
# UNRATE_20180803         NaN
# UNRATE_20180907         NaN
# UNRATE_20181005         NaN
# UNRATE_20181102         NaN
# UNRATE_20181207         3.7
# UNRATE_20190101         3.7
#
# [328 rows x 707 columns]
